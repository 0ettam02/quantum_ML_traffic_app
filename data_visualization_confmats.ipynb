# %% [markdown]
# # Matrice di confusione 100k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output"
]


def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    # Lettura dei file
    pred_filepath = f"output/predictions.dat"
    labels_map_filepath = f"output/labels_map.json"
    with open(labels_map_filepath, 'r') as f:
        labels_map = json.load(f)
    labels_map = {int(k): v for k, v in labels_map.items()}

    df_pred = pd.read_csv(pred_filepath, sep="\t")
    df_pred["Actual"] = df_pred["Actual"].map(labels_map)
    df_pred["Predicted"] = df_pred["Predicted"].map(labels_map)

    y_test = df_pred["Actual"].tolist()
    y_pred = df_pred["Predicted"].tolist()

    # Plotting della matrice di confusione
    cm = confusion_matrix(y_test, y_pred, normalize='true')

    fontsize = 18
    classes = list(labels_map.values())
    
    fig, ax = plt.subplots(figsize=(10, 10))
    im = ax.matshow(cm, cmap='Blues')

    plt.colorbar(im)
    ax.set_xticks(np.arange(len(classes)))
    ax.xaxis.set_ticks_position('bottom')
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(classes, rotation=45, ha='right', fontsize=9)
    ax.set_yticklabels(classes, fontsize=9)
    ax.set_xlabel('Predicted label', fontsize=12)
    ax.set_ylabel('True label', fontsize=12)


    plt.tight_layout()
    plt.savefig(f"{output_dir}/cm.png", dpi=600)
    plt.savefig(f"{output_dir}/cm.pdf", dpi=600)

# %% [markdown]
# # Matrice di confusione 10k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output2"
]


def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    # Lettura dei file
    pred_filepath = f"output2/predictions.dat"
    labels_map_filepath = f"output2/labels_map.json"
    with open(labels_map_filepath, 'r') as f:
        labels_map = json.load(f)
    labels_map = {int(k): v for k, v in labels_map.items()}

    df_pred = pd.read_csv(pred_filepath, sep="\t")
    df_pred["Actual"] = df_pred["Actual"].map(labels_map)
    df_pred["Predicted"] = df_pred["Predicted"].map(labels_map)

    y_test = df_pred["Actual"].tolist()
    y_pred = df_pred["Predicted"].tolist()

    # Plotting della matrice di confusione
    # Plotting della matrice di confusione
    cm = confusion_matrix(y_test, y_pred, normalize='true')

    fontsize = 18
    classes = list(labels_map.values())

    fig, ax = plt.subplots(figsize=(10, 10))

    cmap = plt.cm.Blues
    cmap.set_under('red')   

    im = ax.matshow(cm, cmap=cmap, vmin=1e-6)

    plt.colorbar(im)
    ax.set_xticks(np.arange(len(classes)))
    ax.xaxis.set_ticks_position('bottom')
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(classes, rotation=45, ha='right', fontsize=9)
    ax.set_yticklabels(classes, fontsize=9)
    ax.set_xlabel('Predicted label', fontsize=12)
    ax.set_ylabel('True label', fontsize=12)

    plt.tight_layout()
    plt.savefig(f"{output_dir}/cm.png", dpi=600)
    plt.savefig(f"{output_dir}/cm.pdf", dpi=600)

# %% [markdown]
# # Matrice di confusione 30k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output3"
]


def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    # Lettura dei file
    pred_filepath = f"output2/predictions.dat"
    labels_map_filepath = f"output2/labels_map.json"
    with open(labels_map_filepath, 'r') as f:
        labels_map = json.load(f)
    labels_map = {int(k): v for k, v in labels_map.items()}

    df_pred = pd.read_csv(pred_filepath, sep="\t")
    df_pred["Actual"] = df_pred["Actual"].map(labels_map)
    df_pred["Predicted"] = df_pred["Predicted"].map(labels_map)

    y_test = df_pred["Actual"].tolist()
    y_pred = df_pred["Predicted"].tolist()

    # Plotting della matrice di confusione
    # Plotting della matrice di confusione
    cm = confusion_matrix(y_test, y_pred, normalize='true')

    fontsize = 18
    classes = list(labels_map.values())

    fig, ax = plt.subplots(figsize=(10, 10))

    cmap = plt.cm.Blues
    cmap.set_under('red')   

    im = ax.matshow(cm, cmap=cmap, vmin=1e-6)

    plt.colorbar(im)
    ax.set_xticks(np.arange(len(classes)))
    ax.xaxis.set_ticks_position('bottom')
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(classes, rotation=45, ha='right', fontsize=9)
    ax.set_yticklabels(classes, fontsize=9)
    ax.set_xlabel('Predicted label', fontsize=12)
    ax.set_ylabel('True label', fontsize=12)

    plt.tight_layout()
    plt.savefig(f"{output_dir}/cm.png", dpi=600)
    plt.savefig(f"{output_dir}/cm.pdf", dpi=600)
# Out:
# 2025-11-25 10:37:18.386827: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-25 10:37:18.438572: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-25 10:37:18.438623: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-25 10:37:18.438651: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-25 10:37:18.445679: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-25 10:37:18.446097: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-25 10:37:19.220849: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Matrice di confusione 45k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output4"
]


def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    # Lettura dei file
    pred_filepath = f"output2/predictions.dat"
    labels_map_filepath = f"output2/labels_map.json"
    with open(labels_map_filepath, 'r') as f:
        labels_map = json.load(f)
    labels_map = {int(k): v for k, v in labels_map.items()}

    df_pred = pd.read_csv(pred_filepath, sep="\t")
    df_pred["Actual"] = df_pred["Actual"].map(labels_map)
    df_pred["Predicted"] = df_pred["Predicted"].map(labels_map)

    y_test = df_pred["Actual"].tolist()
    y_pred = df_pred["Predicted"].tolist()

    # Plotting della matrice di confusione
    # Plotting della matrice di confusione
    cm = confusion_matrix(y_test, y_pred, normalize='true')

    fontsize = 18
    classes = list(labels_map.values())

    fig, ax = plt.subplots(figsize=(10, 10))

    cmap = plt.cm.Blues
    cmap.set_under('red')   

    im = ax.matshow(cm, cmap=cmap, vmin=1e-6)

    plt.colorbar(im)
    ax.set_xticks(np.arange(len(classes)))
    ax.xaxis.set_ticks_position('bottom')
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(classes, rotation=45, ha='right', fontsize=9)
    ax.set_yticklabels(classes, fontsize=9)
    ax.set_xlabel('Predicted label', fontsize=12)
    ax.set_ylabel('True label', fontsize=12)

    plt.tight_layout()
    plt.savefig(f"{output_dir}/cm.png", dpi=600)
    plt.savefig(f"{output_dir}/cm.pdf", dpi=600)

# %% [markdown]
# # Matrice di confusione 50k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output5"
]


def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    # Lettura dei file
    pred_filepath = f"output2/predictions.dat"
    labels_map_filepath = f"output2/labels_map.json"
    with open(labels_map_filepath, 'r') as f:
        labels_map = json.load(f)
    labels_map = {int(k): v for k, v in labels_map.items()}

    df_pred = pd.read_csv(pred_filepath, sep="\t")
    df_pred["Actual"] = df_pred["Actual"].map(labels_map)
    df_pred["Predicted"] = df_pred["Predicted"].map(labels_map)

    y_test = df_pred["Actual"].tolist()
    y_pred = df_pred["Predicted"].tolist()

    # Plotting della matrice di confusione
    # Plotting della matrice di confusione
    cm = confusion_matrix(y_test, y_pred, normalize='true')

    fontsize = 18
    classes = list(labels_map.values())

    fig, ax = plt.subplots(figsize=(10, 10))

    cmap = plt.cm.Blues
    cmap.set_under('red')   

    im = ax.matshow(cm, cmap=cmap, vmin=1e-6)

    plt.colorbar(im)
    ax.set_xticks(np.arange(len(classes)))
    ax.xaxis.set_ticks_position('bottom')
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(classes, rotation=45, ha='right', fontsize=9)
    ax.set_yticklabels(classes, fontsize=9)
    ax.set_xlabel('Predicted label', fontsize=12)
    ax.set_ylabel('True label', fontsize=12)

    plt.tight_layout()
    plt.savefig(f"{output_dir}/cm.png", dpi=600)
    plt.savefig(f"{output_dir}/cm.pdf", dpi=600)
