# %% [markdown]
# # Grafico training-loss 100k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output"
]

def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    history_df = pd.read_csv(f"{output_dir}/training_history.csv")

    accuracy = history_df["accuracy"].tolist()
    val_accuracy = history_df["val_accuracy"].tolist()
    loss = history_df["loss"].tolist()
    val_loss = history_df["val_loss"].tolist()

    plt.figure(figsize=(8, 5))
    plt.plot([a*100 for a in accuracy], label="Training Accuracy")
    plt.plot([a*100 for a in val_accuracy], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("%")
    plt.title("Accuracy across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/accuracy_history.png", dpi=600)
    plt.savefig(f"{output_dir}/accuracy_history.pdf", dpi=600)

    plt.figure(figsize=(8, 5))
    plt.plot(loss, label="Training Loss")
    plt.plot(val_loss, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("")
    plt.title("Loss across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/loss_history.png", dpi=600)
    plt.savefig(f"{output_dir}/loss_history.pdf", dpi=600)

# %% [markdown]
# # Grafico training-loss 10k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output2"
]

def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    history_df = pd.read_csv(f"{output_dir}/training_history.csv")

    accuracy = history_df["accuracy"].tolist()
    val_accuracy = history_df["val_accuracy"].tolist()
    loss = history_df["loss"].tolist()
    val_loss = history_df["val_loss"].tolist()

    plt.figure(figsize=(8, 5))
    plt.plot([a*100 for a in accuracy], label="Training Accuracy")
    plt.plot([a*100 for a in val_accuracy], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("%")
    plt.title("Accuracy across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/accuracy_history.png", dpi=600)
    plt.savefig(f"{output_dir}/accuracy_history.pdf", dpi=600)

    plt.figure(figsize=(8, 5))
    plt.plot(loss, label="Training Loss")
    plt.plot(val_loss, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("")
    plt.title("Loss across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/loss_history.png", dpi=600)
    plt.savefig(f"{output_dir}/loss_history.pdf", dpi=600)

# %% [markdown]
# # Grafico training-loss 30k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output3"
]

def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    history_df = pd.read_csv(f"{output_dir}/training_history.csv")

    accuracy = history_df["accuracy"].tolist()
    val_accuracy = history_df["val_accuracy"].tolist()
    loss = history_df["loss"].tolist()
    val_loss = history_df["val_loss"].tolist()

    plt.figure(figsize=(8, 5))
    plt.plot([a*100 for a in accuracy], label="Training Accuracy")
    plt.plot([a*100 for a in val_accuracy], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("%")
    plt.title("Accuracy across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/accuracy_history.png", dpi=600)
    plt.savefig(f"{output_dir}/accuracy_history.pdf", dpi=600)

    plt.figure(figsize=(8, 5))
    plt.plot(loss, label="Training Loss")
    plt.plot(val_loss, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("")
    plt.title("Loss across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/loss_history.png", dpi=600)
    plt.savefig(f"{output_dir}/loss_history.pdf", dpi=600)
# Out:
# 2025-11-25 10:35:56.848230: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-25 10:35:56.886133: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-25 10:35:56.886180: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-25 10:35:56.886222: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-25 10:35:56.893382: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-25 10:35:56.893891: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-25 10:35:57.641833: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Grafico training-loss 45k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output4"
]

def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    history_df = pd.read_csv(f"{output_dir}/training_history.csv")

    accuracy = history_df["accuracy"].tolist()
    val_accuracy = history_df["val_accuracy"].tolist()
    loss = history_df["loss"].tolist()
    val_loss = history_df["val_loss"].tolist()

    plt.figure(figsize=(8, 5))
    plt.plot([a*100 for a in accuracy], label="Training Accuracy")
    plt.plot([a*100 for a in val_accuracy], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("%")
    plt.title("Accuracy across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/accuracy_history.png", dpi=600)
    plt.savefig(f"{output_dir}/accuracy_history.pdf", dpi=600)

    plt.figure(figsize=(8, 5))
    plt.plot(loss, label="Training Loss")
    plt.plot(val_loss, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("")
    plt.title("Loss across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/loss_history.png", dpi=600)
    plt.savefig(f"{output_dir}/loss_history.pdf", dpi=600)

# %% [markdown]
# # Grafico training-loss 50k

# %%
import argparse
import os
import pickle
import numpy as np
import tensorflow as tf
import pandas as pd
import json
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
sys.argv = [
    "script.py",
    "--input-dir", "input",
    "--output-dir", "output5"
]

def get_args():
    parser = argparse.ArgumentParser(
        description="Parse the script arguments."
    )


    parser.add_argument(
        "--input-dir",
        type=str,
        required=True,
        help="Path to the input (aka results) directory."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Path to the output directory."
    )

    return parser.parse_args()

if __name__ == "__main__":
    # Parsing degli argomenti
    args = get_args()
    input_dir = args.input_dir
    output_dir = args.output_dir

    history_df = pd.read_csv(f"{output_dir}/training_history.csv")

    accuracy = history_df["accuracy"].tolist()
    val_accuracy = history_df["val_accuracy"].tolist()
    loss = history_df["loss"].tolist()
    val_loss = history_df["val_loss"].tolist()

    plt.figure(figsize=(8, 5))
    plt.plot([a*100 for a in accuracy], label="Training Accuracy")
    plt.plot([a*100 for a in val_accuracy], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("%")
    plt.title("Accuracy across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/accuracy_history.png", dpi=600)
    plt.savefig(f"{output_dir}/accuracy_history.pdf", dpi=600)

    plt.figure(figsize=(8, 5))
    plt.plot(loss, label="Training Loss")
    plt.plot(val_loss, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("")
    plt.title("Loss across epochs")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{output_dir}/loss_history.png", dpi=600)
    plt.savefig(f"{output_dir}/loss_history.pdf", dpi=600)

# %% [markdown]
# # Istogramma

# %%
import argparse
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

sys.argv = [
    "script.py",
    "--input100k", "output",
    "--input50k",  "output5",
    "--output-dir", "merged_output"
]

def get_args():
    parser = argparse.ArgumentParser(
        description="Generate class distribution histograms from predictions."
    )

    parser.add_argument(
        "--input100k",
        type=str,
        required=True,
        help="Directory containing predictions.dat and labels_map.json for 100k dataset."
    )

    parser.add_argument(
        "--input50k",
        type=str,
        required=True,
        help="Directory containing predictions.dat and labels_map.json for 50k dataset."
    )

    parser.add_argument(
        "--output-dir",
        type=str,
        required=True,
        help="Directory where output histograms will be saved."
    )

    return parser.parse_args()


def load_distribution(pred_path, label_map_path):
    df = pd.read_csv(pred_path, sep="\t")

    pred_ids = df["Actual"].values

    with open(label_map_path, "r") as f:
        labels_map = json.load(f)

    label_names = [labels_map[str(i)] for i in pred_ids]

    series = pd.Series(label_names)
    counts = series.value_counts().sort_index()
    percentages = counts / counts.sum() * 100

    return percentages



def plot_histogram(percentages, title, output_path):
    plt.figure(figsize=(10, 5))
    percentages.plot(kind="bar")
    plt.ylabel("Percentuale (%)")
    plt.xlabel("Classe")
    plt.title(title)
    plt.grid(axis="y")
    plt.tight_layout()
    plt.savefig(output_path + ".png", dpi=600)
    plt.savefig(output_path + ".pdf", dpi=600)
    plt.close()


if __name__ == "__main__":
    args = get_args()

    os.makedirs(args.output_dir, exist_ok=True)

    pred_100k = f"{args.input100k}/predictions.dat"
    map_100k  = f"{args.input100k}/labels_map.json"

    pred_50k = f"{args.input50k}/predictions.dat"
    map_50k  = f"{args.input50k}/labels_map.json"

    perc_100k = load_distribution(pred_100k, map_100k)
    perc_50k = load_distribution(pred_50k, map_50k)

    plot_histogram(
        perc_100k,
        "Distribuzione percentuale classi – Dataset 100k",
        f"{args.output_dir}/class_distribution_100k"
    )

    plot_histogram(
        perc_50k,
        "Distribuzione percentuale classi – Dataset 50k",
        f"{args.output_dir}/class_distribution_50k"
    )

# %%
np.fromfile("output/predictions.dat", dtype=np.float32)[:20]
np.fromfile("output/predictions.dat", dtype=np.int32)[:20]
# Out:
# array([1970561857, 1342794849, 1768187250, 1684370531,  154219018,
#         822751538,  171444534,  822687793,  909183544,  171323657,
#         171510073,  170985777,  822688049,  154405433,  909183540,
#         171323657,  839465266,  154536505,  822751282,  909183286],
#       dtype=int32)
